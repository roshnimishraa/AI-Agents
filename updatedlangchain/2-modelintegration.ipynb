# %% [markdown]
# ### Models Integration with NVIDIA, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["NVIDIA_API_KEY"]= os.getenv("NVIDIA_API_KEY")
os.environ["GOOGLE_API_KEY"]= os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "meta/llama-3.1-70b-instruct",
    model_provider="nvidia"
)

model
# Out:
# ChatNVIDIA(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11', 'langchain-nvidia-ai-endpoints': '1.4.2'}}, output_version=None, profile={'max_input_tokens': 128000, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True}, base_url='https://integrate.api.nvidia.com/v1', model='meta/llama-3.1-70b-instruct', default_headers={}, model_kwargs={})

# %%
# invoke the model
response = model.invoke("Hello how are you?")
response
# Out:
# AIMessage(content="I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help you with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'role': 'assistant', 'content': "I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help you with any questions or tasks you may have. How about you? How's your day going so far?", 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': None, 'reasoning_content': None, 'token_usage': {'prompt_tokens': 40, 'total_tokens': 91, 'completion_tokens': 51, 'prompt_tokens_details': None}, 'finish_reason': 'stop', 'model_name': 'meta/llama-3.1-70b-instruct'}, id='lc_run--019ef8c7-2bb6-7e92-9ae2-ac44efb01be2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 51, 'total_tokens': 91}, role='assistant')
